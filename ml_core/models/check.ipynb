# %%
import pandas as pd
df = pd.read_csv('../data/syn_auth_login_fixed.csv')

# %%
df.head()
# Out:
#      login_id   user_id            timestamp  hour_of_day  day_of_week  \
# 0  LGN0008413  USR00170  2024-03-10T08:52:00            8            6
# 1  LGN0012443  USR00091  2024-11-23T02:29:00            2            5
# 2  LGN0016247  USR00004  2025-04-29T22:41:00           22            1
# 3  LGN0010649  USR00134  2024-11-19T09:22:00            9            1
# 4  LGN0008046  USR00163  2024-02-19T15:31:00           15            0
#
#         ip_address      asn        isp_name      ip_type country  ...  \
# 0  192.181.203.185  AS38182  Dishhome Fiber  residential      NP  ...
# 1   202.40.148.148  AS45650             UTL  residential      NP  ...
# 2     103.87.87.54  AS45650          Subisu  residential      NP  ...
# 3   110.117.53.206   AS9829      NTC Mobile       mobile      NP  ...
# 4    110.171.43.49   AS9829      NTC Mobile       mobile      NP  ...
#
#   hour_deviation  ms_between_attempts  fail_count_before_success  \
# ...

# %%
df['ip_type'].value_counts()
# Out:
# ip_type
# residential    14615
# mobile          4304
# vpn              538
# datacenter       375
# tor               50
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['login_id', 'user_id', 'timestamp', 'hour_of_day', 'day_of_week',
#        'ip_address', 'asn', 'isp_name', 'ip_type', 'country', 'city',
#        'latitude', 'longitude', 'device_os', 'device_browser',
#        'device_fingerprint', 'is_new_device', 'is_known_vpn',
#        'is_datacenter_ip', 'is_tor', 'is_foreign', 'high_distance',
#        'suspicious_isp', 'velocity_last_1hr', 'velocity_last_24hr',
#        'velocity_ratio', 'distance_from_last_login_km',
#        'hours_since_last_login', 'impossible_travel', 'hour_deviation',
#        'ms_between_attempts', 'fail_count_before_success',
#        'device_trust_score', 'user_baseline_hour_mean',
#        'user_baseline_hour_std', 'user_account_age_days', 'ip_reputation',
#        'label', 'anomaly_type'],
#       dtype='object')

# %%
df['device_os'].value_counts()
# Out:
# device_os
# Android    12582
# Windows     3285
# iOS         2570
# Linux       1138
# macOS        307
# Name: count, dtype: int64
